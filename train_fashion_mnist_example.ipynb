# %%
import argparse
from typing import Dict

import torch
import ray.train as train
from ray.train.trainer import Trainer
from ray.train.callbacks import JsonLoggerCallback
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor

# %%
print (torch.cuda.is_available())
# Out:
# True

# %%
# Download training data from open datasets.
training_data = datasets.FashionMNIST(
    root="~/data",
    train=True,
    download=True,
    transform=ToTensor(),
)

# %%
# Download test data from open datasets.
test_data = datasets.FashionMNIST(
    root="~/data",
    train=False,
    download=True,
    transform=ToTensor(),
)

# %%
# Define model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28 * 28, 512), nn.ReLU(), nn.Linear(512, 512), nn.ReLU(),
            nn.Linear(512, 10), nn.ReLU())

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

# %%
def train_epoch(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    for batch, (X, y) in enumerate(dataloader):
        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

# %%
def validate_epoch(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n "
          f"Accuracy: {(100 * correct):>0.1f}%, "
          f"Avg loss: {test_loss:>8f} \n")
    return test_loss

# %%
def train_func(config: Dict):
    batch_size = config["batch_size"]
    lr = config["lr"]
    epochs = config["epochs"]

    # Create data loaders.
    train_dataloader = DataLoader(training_data, batch_size=batch_size)
    test_dataloader = DataLoader(test_data, batch_size=batch_size)

    train_dataloader = train.torch.prepare_data_loader(train_dataloader)
    test_dataloader = train.torch.prepare_data_loader(test_dataloader)

    # Create model.
    model = NeuralNetwork()
    model = train.torch.prepare_model(model)

    loss_fn = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=lr)

    loss_results = []

    for _ in range(epochs):
        train_epoch(train_dataloader, model, loss_fn, optimizer)
        loss = validate_epoch(test_dataloader, model, loss_fn)
        train.report(loss=loss)
        loss_results.append(loss)

    return loss_results

# %%
def train_fashion_mnist(num_workers=2, use_gpu=False):
    trainer = Trainer(
        backend="torch", num_workers=num_workers, use_gpu=use_gpu)
    trainer.start()
    result = trainer.run(
        train_func=train_func,
        config={
            "lr": 1e-3,
            "batch_size": 64,
            "epochs": 4
        },
        callbacks=[JsonLoggerCallback()])
    trainer.shutdown()
    print(f"Loss results: {result}")

# %%
if __name__ == "__main__":
    parser = argparse.ArgumentParser()
    parser.add_argument(
        "--address",
        required=False,
        type=str,
        help="the address to use for Ray")
    parser.add_argument(
        "--num-workers",
        "-n",
        type=int,
        default=4,
        help="Sets number of workers for training.")
    parser.add_argument(
        "--use-gpu",
        action="store_true",
        default=True,
        help="Enables GPU training")
    parser.add_argument(
        "--smoke-test",
        action="store_true",
        default=False,
        help="Finish quickly for testing.")

    args, _ = parser.parse_known_args()

    import ray

    if args.smoke_test:
        ray.init(num_cpus=2)
    else:
        ray.init(address=args.address)
    train_fashion_mnist(num_workers=args.num_workers, use_gpu=args.use_gpu)
# Out:
# 2022-02-20 14:00:52,422	INFO services.py:1374 -- View the Ray dashboard at http://127.0.0.1:8266
# 2022-02-20 14:00:54,281	INFO trainer.py:190 -- Trainer logs will be logged in: /home/steve/ray_results/train_2022-02-20_14-00-54
# (BaseWorkerMixin pid=29111) 2022-02-20 14:00:56,690	INFO torch.py:66 -- Setting up process group for: env:// [rank=0, world_size=4]
# (BaseWorkerMixin pid=29104) 2022-02-20 14:00:56,684	INFO torch.py:66 -- Setting up process group for: env:// [rank=3, world_size=4]
# (BaseWorkerMixin pid=29101) 2022-02-20 14:00:56,685	INFO torch.py:66 -- Setting up process group for: env:// [rank=1, world_size=4]
# (BaseWorkerMixin pid=29108) 2022-02-20 14:00:56,720	INFO torch.py:66 -- Setting up process group for: env:// [rank=2, world_size=4]
# 2022-02-20 14:00:57,827	INFO trainer.py:196 -- Run results will be logged in: /home/steve/ray_results/train_2022-02-20_14-00-54/run_001
# (BaseWorkerMixin pid=29104) 2022-02-20 14:00:59,009	INFO torch.py:239 -- Moving model to device: cuda:3
# (BaseWorkerMixin pid=29101) 2022-02-20 14:00:59,014	INFO torch.py:239 -- Moving model to device: cuda:1
# (BaseWorkerMixin pid=29108) 2022-02-20 14:00:59,015	INFO torch.py:239 -- Moving model to device: cuda:2
# (BaseWorkerMixin pid=29111) 2022-02-20 14:00:59,539	INFO torch.py:239 -- Moving model to device: cuda:0
# (BaseWorkerMixin pid=29104) 2022-02-20 14:01:03,360	INFO torch.py:242 -- Wrapping provided model in DDP.
# (BaseWorkerMixin pid=29101) 2022-02-20 14:01:03,416	INFO torch.py:242 -- Wrapping provided model in DDP.
# (BaseWorkerMixin pid=29108) 2022-02-20 14:01:03,394	INFO torch.py:242 -- Wrapping provided model in DDP.
# (BaseWorkerMixin pid=29111) 2022-02-20 14:01:04,023	INFO torch.py:242 -- Wrapping provided model in DDP.
# (BaseWorkerMixin pid=29111) loss: 2.311540  [    0/60000]
# (BaseWorkerMixin pid=29104) loss: 2.310010  [    0/60000]
# (BaseWorkerMixin pid=29108) loss: 2.307373  [    0/60000]
# (BaseWorkerMixin pid=29101) loss: 2.308183  [    0/60000]
# (BaseWorkerMixin pid=29111) loss: 2.304651  [ 6400/60000]
# (BaseWorkerMixin pid=29104) loss: 2.300238  [ 6400/60000]
# (BaseWorkerMixin pid=29108) loss: 2.290715  [ 6400/60000]
# (BaseWorkerMixin pid=29101) loss: 2.301900  [ 6400/60000]
# (BaseWorkerMixin pid=29111) loss: 2.299919  [12800/60000]
# (BaseWorkerMixin pid=29104) loss: 2.293612  [12800/60000]
# (BaseWorkerMixin pid=29108) loss: 2.287717  [12800/60000]
# (BaseWorkerMixin pid=29101) loss: 2.298029  [12800/60000]
# (BaseWorkerMixin pid=29111) Test Error:
# (BaseWorkerMixin pid=29111)  Accuracy: 6.1%, Avg loss: 2.287458
# (BaseWorkerMixin pid=29111)
# (BaseWorkerMixin pid=29104) Test Error:
# (BaseWorkerMixin pid=29104)  Accuracy: 6.0%, Avg loss: 2.288760
# (BaseWorkerMixin pid=29104)
# (BaseWorkerMixin pid=29108) Test Error:
# (BaseWorkerMixin pid=29108)  Accuracy: 6.4%, Avg loss: 2.286781
# (BaseWorkerMixin pid=29108)
# (BaseWorkerMixin pid=29101) Test Error:
# (BaseWorkerMixin pid=29101)  Accuracy: 6.1%, Avg loss: 2.288951
# (BaseWorkerMixin pid=29101)
# (BaseWorkerMixin pid=29111) loss: 2.292288  [    0/60000]
# (BaseWorkerMixin pid=29104) loss: 2.288743  [    0/60000]
# (BaseWorkerMixin pid=29108) loss: 2.288341  [    0/60000]
# (BaseWorkerMixin pid=29101) loss: 2.288014  [    0/60000]
# (BaseWorkerMixin pid=29111) loss: 2.289859  [ 6400/60000]
# (BaseWorkerMixin pid=29104) loss: 2.280181  [ 6400/60000]
# (BaseWorkerMixin pid=29108) loss: 2.266452  [ 6400/60000]
# (BaseWorkerMixin pid=29101) loss: 2.283058  [ 6400/60000]
# (BaseWorkerMixin pid=29111) loss: 2.286662  [12800/60000]
# (BaseWorkerMixin pid=29104) loss: 2.277352  [12800/60000]
# (BaseWorkerMixin pid=29108) loss: 2.269640  [12800/60000]
# (BaseWorkerMixin pid=29101) loss: 2.283403  [12800/60000]
# (BaseWorkerMixin pid=29111) Test Error:
# (BaseWorkerMixin pid=29111)  Accuracy: 9.9%, Avg loss: 2.268445
# (BaseWorkerMixin pid=29111)
# (BaseWorkerMixin pid=29111) loss: 2.276653  [    0/60000]
# (BaseWorkerMixin pid=29104) Test Error:
# (BaseWorkerMixin pid=29104)  Accuracy: 9.6%, Avg loss: 2.270822
# (BaseWorkerMixin pid=29104)
# (BaseWorkerMixin pid=29104) loss: 2.270373  [    0/60000]
# (BaseWorkerMixin pid=29108) Test Error:
# (BaseWorkerMixin pid=29108)  Accuracy: 10.0%, Avg loss: 2.267671
# (BaseWorkerMixin pid=29108)
# (BaseWorkerMixin pid=29108) loss: 2.269403  [    0/60000]
# (BaseWorkerMixin pid=29101) Test Error:
# (BaseWorkerMixin pid=29101)  Accuracy: 9.5%, Avg loss: 2.271284
# (BaseWorkerMixin pid=29101)
# (BaseWorkerMixin pid=29101) loss: 2.270374  [    0/60000]
# (BaseWorkerMixin pid=29111) loss: 2.274502  [ 6400/60000]
# (BaseWorkerMixin pid=29104) loss: 2.261236  [ 6400/60000]
# (BaseWorkerMixin pid=29108) loss: 2.242391  [ 6400/60000]
# (BaseWorkerMixin pid=29101) loss: 2.265100  [ 6400/60000]
# (BaseWorkerMixin pid=29111) loss: 2.273263  [12800/60000]
# (BaseWorkerMixin pid=29104) loss: 2.260846  [12800/60000]
# (BaseWorkerMixin pid=29108) loss: 2.249800  [12800/60000]
# (BaseWorkerMixin pid=29101) loss: 2.268341  [12800/60000]
# (BaseWorkerMixin pid=29104) Test Error:
# (BaseWorkerMixin pid=29104)  Accuracy: 11.0%, Avg loss: 2.251877
# (BaseWorkerMixin pid=29104)
# (BaseWorkerMixin pid=29108) Test Error:
# (BaseWorkerMixin pid=29108)  Accuracy: 11.4%, Avg loss: 2.247584
# (BaseWorkerMixin pid=29108)
# (BaseWorkerMixin pid=29101) Test Error:
# (BaseWorkerMixin pid=29101)  Accuracy: 10.7%, Avg loss: 2.252749
# (BaseWorkerMixin pid=29101)
# (BaseWorkerMixin pid=29111) Test Error:
# (BaseWorkerMixin pid=29111)  Accuracy: 11.1%, Avg loss: 2.248413
# (BaseWorkerMixin pid=29111)
# (BaseWorkerMixin pid=29111) loss: 2.260326  [    0/60000]
# (BaseWorkerMixin pid=29104) loss: 2.251201  [    0/60000]
# (BaseWorkerMixin pid=29108) loss: 2.249017  [    0/60000]
# (BaseWorkerMixin pid=29101) loss: 2.251994  [    0/60000]
# (BaseWorkerMixin pid=29111) loss: 2.257599  [ 6400/60000]
# (BaseWorkerMixin pid=29104) loss: 2.241304  [ 6400/60000]
# (BaseWorkerMixin pid=29108) loss: 2.216225  [ 6400/60000]
# (BaseWorkerMixin pid=29101) loss: 2.245572  [ 6400/60000]
# (BaseWorkerMixin pid=29111) loss: 2.259245  [12800/60000]
# (BaseWorkerMixin pid=29104) loss: 2.243469  [12800/60000]
# (BaseWorkerMixin pid=29108) loss: 2.228292  [12800/60000]
# (BaseWorkerMixin pid=29101) loss: 2.251925  [12800/60000]
# (BaseWorkerMixin pid=29111) Test Error:
# (BaseWorkerMixin pid=29111)  Accuracy: 11.4%, Avg loss: 2.226610
# (BaseWorkerMixin pid=29111)
# (BaseWorkerMixin pid=29104) Test Error:
# (BaseWorkerMixin pid=29104)  Accuracy: 11.2%, Avg loss: 2.231324
# (BaseWorkerMixin pid=29104)
# (BaseWorkerMixin pid=29108) Test Error:
# (BaseWorkerMixin pid=29108)  Accuracy: 11.6%, Avg loss: 2.225766
# (BaseWorkerMixin pid=29108)
# (BaseWorkerMixin pid=29101) Test Error:
# (BaseWorkerMixin pid=29101)  Accuracy: 10.8%, Avg loss: 2.232672
# (BaseWorkerMixin pid=29101)
# Loss results: [[2.28745813369751, 2.268444675207138, 2.24841313958168, 2.226609671115875], [2.288951462507248, 2.271283966302872, 2.2527486741542817, 2.232671970129013], [2.286780798435211, 2.267671012878418, 2.247584122419357, 2.2257664144039153], [2.2887598633766175, 2.270821803808212, 2.2518765330314636, 2.2313236474990843]]
